# %%
from funasr import AutoModel
print("AutoModel imported successfully!")
# Out:
# AutoModel imported successfully!

# %%
from modelscope.pipelines import pipeline
import torch

print("CUDA available:", torch.cuda.is_available())
device = 'gpu' if torch.cuda.is_available() else 'cpu'

pipe = pipeline(
    task='auto-speech-recognition',
    model='iic/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch',
    device=device
)

result = pipe("t-ngamuk.wav")

# ✅ Handle list output
if isinstance(result, list):
    chinese_text = "".join([seg["text"] for seg in result])
else:
    chinese_text = result["text"]

print("Chinese Transcript:", chinese_text)
# Out:
# CUDA available: True
# 2025-12-04 20:58:32,150 - modelscope - WARNING - Model revision not specified, use revision: v2.0.4
# 2025-12-04 20:58:32,670 - modelscope - INFO - initiate model from C:\Users\User\.cache\modelscope\hub\iic\speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch
# 2025-12-04 20:58:32,671 - modelscope - INFO - initiate model from location C:\Users\User\.cache\modelscope\hub\iic\speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch.
# 2025-12-04 20:58:32,677 - modelscope - INFO - initialize model from C:\Users\User\.cache\modelscope\hub\iic\speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch
# funasr version: 1.2.7.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# WARNING:root:trust_remote_code: False
# You are using the latest version of funasr-1.2.7
# 2025-12-04 20:58:35,237 - modelscope - WARNING - No preprocessor field found in cfg.
# 2025-12-04 20:58:35,238 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2025-12-04 20:58:35,238 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': 'C:\\Users\\User\\.cache\\modelscope\\hub\\iic\\speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch'}. trying to build by task and model information.
# 2025-12-04 20:58:35,239 - modelscope - WARNING - No preprocessor key ('funasr', 'auto-speech-recognition') found in PREPROCESSOR_MAP, skip building preprocessor.
# rtf_avg: 0.006: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Chinese Transcript: 我要跟各位讲为什么日本理亏嘛所现在中国大陆在做什么事情我们自己的国土拿回来了现在改变了过去是日本军舰在巡索巡逻钓鱼台然后就要认国国国不不过国对现在变成中国大陆在巡捕盗人台那是中国的领土我要跟各位讲要鼓掌那是属于我们新国的的叛徒所以我跟各位讲这段历史的就因是什么日要就是侵略者人日本人是侵国国人日人日国的强盗人你要认清这个事实啊该不该打他就是叛他你在台湾讲说不该打日本人的就是叛徒我要必打他就是叛徒日本人侵略中国杀了多少人呐那种暴侵是多残人人日本人要本国国的人竟竟然说要原谅日本人杀你新加坡人看看现在人杀你新加坡人看看看在不是是你新加坡人三千多少人呐你讲什么屁话我要跟各位讲认清历史的事徒更要认清日本军国主义的真实面目对现要再被欺负了他认被日本人的的人那我今人你还侵国国吗他还不过来来日本本要被日本的的叛徒人要变成中国民族的叛徒所以他不承认自己是中华民族的人今天还要出来支持日本战什么支持日本那个侵略者来欺负中华民族的同胞你就是叛徒人要诸之可以我告诉各位日国是历史的事实就是我们真正的事实我们不要讲其他的就讲这一点日本人就该做什么所以我要跟各位讲快了日本人不要做嘴软千万不要嘴软美国人你再去顶顶看美国人跑的是比谁都快我告诉各位美国人打不过中国大陆现在的美国了美国国美美国打不过我你你美国国我告各各了我国这国而了美国人就日本人出来弄了各现我告诉各位这次美国也会吃大亏所以你今天真的跟日本站在一起你去协防嘛中国大陆现在所有的战略所有的目标已经清楚了他现在都准备好了他现在就等你看你嘴硬到什么时候看你美国要到什么时候他现在习近国主席跟川普讲的只是么克的的话你是告诉国国我要对不起你美美国人最往往跑跑一一嘛美得我打日本人是打到你美国就这么简单而已你不要认为还有什么客套化没有客套话中国大陆已经准备好了另外我再跟各位讲俄国为什么要找防御去俄国对为现在就国国手了嘛日国国国什么下手所到国国的之后你就知道了所以我可以各位讲这个国势绝对不是日本人那种日日梦准备过了
